# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshyadav3112/PYTHON/blob/main/ipl_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
match=pd.read_csv('/content/Match.csv')

# %%
match
# Out:
#      Match_SK  match_id                        Team1  \
# 0           0    335987  Royal Challengers Bangalore
# 1           1    335988              Kings XI Punjab
# 2           2    335989             Delhi Daredevils
# 3           3    335990               Mumbai Indians
# 4           4    335991        Kolkata Knight Riders
# ..        ...       ...                          ...
# 632       632   1082646             Delhi Daredevils
# 633       633   1082647               Mumbai Indians
# 634       634   1082648          Sunrisers Hyderabad
# 635       635   1082649               Mumbai Indians
# 636       636   1082650               Mumbai Indians
#
#                            Team2 match_date  Season_Year  \
# 0          Kolkata Knight Riders  4/18/2008         2008
# 1            Chennai Super Kings  4/19/2008         2008
# 2               Rajasthan Royals  4/19/2008         2008
# 3    Royal Challengers Bangalore  4/20/2008         2008
# ...

# %%
match.shape
# Out:
# (637, 17)

# %%
match['ManOfMach'].value_counts()
# Out:
# ManOfMach
# CH Gayle          18
# YK Pathan         16
# AB de Villiers    15
# DA Warner         15
# RG Sharma         14
#                   ..
# MD Mishra          1
# SB Wagh            1
# S Anirudha         1
# M Kartik           1
# KV Sharma          1
# Name: count, Length: 202, dtype: int64

# %%
match['ManOfMach'].value_counts()[0:10]
# Out:
# ManOfMach
# CH Gayle          18
# YK Pathan         16
# AB de Villiers    15
# DA Warner         15
# RG Sharma         14
# SK Raina          14
# MS Dhoni          13
# G Gambhir         13
# MEK Hussey        12
# AM Rahane         12
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
plt.bar(list(match['ManOfMach'].value_counts()[0:5].keys()) ,  list(match['ManOfMach'].value_counts()[0:5]),color='g')
plt.show()

# %%
match['Win_Type'].value_counts()
# Out:
# Win_Type
# wickets      339
# runs         286
# Tie            6
# NO Result      3
# run            1
# Name: count, dtype: int64

# %%
match['Toss_Winner'].value_counts()
# Out:
# Toss_Winner
# Mumbai Indians                 85
# Kolkata Knight Riders          78
# Delhi Daredevils               72
# Royal Challengers Bangalore    70
# Kings XI Punjab                68
# Chennai Super Kings            66
# Rajasthan Royals               63
# Deccan Chargers                43
# Sunrisers Hyderabad            35
# Pune Warriors                  20
# Gujarat Lions                  15
# Rising Pune Supergiants        12
# Kochi Tuskers Kerala            8
# Rising Pune Supergiant          1
# Name: count, dtype: int64

# %%
batting_first=match[match['Win_Margin']!=0]

# %%
batting_first.head()
# Out:
#    Match_SK  match_id                        Team1  \
# 0         0    335987  Royal Challengers Bangalore
# 1         1    335988              Kings XI Punjab
# 2         2    335989             Delhi Daredevils
# 3         3    335990               Mumbai Indians
# 4         4    335991        Kolkata Knight Riders
#
#                          Team2 match_date  Season_Year  \
# 0        Kolkata Knight Riders  4/18/2008         2008
# 1          Chennai Super Kings  4/19/2008         2008
# 2             Rajasthan Royals  4/19/2008         2008
# 3  Royal Challengers Bangalore  4/20/2008         2008
# 4              Deccan Chargers  4/20/2008         2008
#
#                                    Venue_Name   City_Name Country_Name  \
# 0                       M Chinnaswamy Stadium   Bangalore        India
# 1  Punjab Cricket Association Stadium, Mohali  Chandigarh        India
# 2                            Feroz Shah Kotla       Delhi        India
# ...

# %%
plt.figure(figsize=(5,5))
plt.hist(batting_first['Win_Margin'])
plt.title('Winning_team')
plt.xlabel('Runs')
plt.show()

# %%
batting_first['match_winner'].value_counts()
# Out:
# match_winner
# Mumbai Indians                 91
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Rising Pune Supergiants        15
# Gujarat Lions                  13
# Pune Warriors                  12
# Kochi Tuskers Kerala            6
# Name: count, dtype: int64

# %%
plt.figure(figsize=(14,5))
plt.bar(list(batting_first['match_winner'].value_counts()[0:5].keys()),list(batting_first['match_winner'].value_counts()[0:5]),color=['r','g','b','y','b'])
plt.show()

# %%
plt.figure(figsize=(14,5))
plt.pie(list(batting_first['match_winner'].value_counts()[0:5]),labels=list(batting_first['match_winner'].value_counts()[0:5].keys()),autopct='%0.1f%%')
plt.show()

# %%
match['Season_Year'].value_counts()
# Out:
# Season_Year
# 2013    76
# 2012    74
# 2011    73
# 2010    60
# 2014    60
# 2016    60
# 2017    60
# 2015    59
# 2008    58
# 2009    57
# Name: count, dtype: int64

# %%
match['City_Name'].value_counts()
# Out:
# City_Name
# Mumbai                85
# Kolkata               61
# Delhi                 60
# Bangalore             58
# Chennai               48
# Chandigarh            42
# Hyderabad             41
# Jaipur                33
# Pune                  32
# Abu Dhabi             20
# Durban                15
# Ahmedabad             12
# Centurion             12
# Visakhapatnam         11
# Rajkot                10
# Bengaluru              9
# Dharamsala             9
# Hyderabad (Deccan)     8
# Johannesburg           8
# Cuttack                7
# Port Elizabeth         7
# Ranchi                 7
# Cape Town              7
# Raipur                 6
# Kochi                  5
# Indore                 5
# Kanpur                 4
# Mohali                 4
# Nagpur                 3
# Kimberley              3
# East London            3
# Bloemfontein           2
# Name: count, dtype: int64

# %%
toss_win=np.sum(match['Toss_Winner']==match['match_winner'])

# %%
toss_win
# Out:
# 324

# %%
324/637*100
# Out:
# 50.86342229199372

# %%
deliveries=pd.read_csv('/content/deliveries.csv')

# %%
deliveries.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum           0.0         1.0
# 1     2  BB McCullum  P Kumar   SC Ganguly           0.0         0.0
# 2     3  BB McCullum  P Kumar   SC Ganguly           0.0         1.0
# 3     4  BB McCullum  P Kumar   SC Ganguly           0.0         0.0
# 4     5  BB McCullum  P Kumar   SC Ganguly           0.0         0.0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
deliveries.shape
# Out:
# (40750, 17)

# %%
deliveries['match_id'].unique()
# Out:
# array([335982, 335983, 335984, 335985, 335986, 335987, 335988, 335989,
#        335990, 335991, 335992, 335993, 335994, 335995, 335996, 335997,
#        335998, 335999, 336000, 336001, 336002, 336003, 336004, 336005,
#        336006, 336007, 336008, 336009, 336010, 336011, 336012, 336013,
#        336014, 336015, 336016, 336017, 336018, 336019, 336020, 336021,
#        336022, 336023, 336024, 336025, 336026, 336027, 336028, 336029,
#        336031, 336032, 336033, 336034, 336035, 336036, 336037, 336038,
#        336039, 336040, 392181, 392182, 392183, 392184, 392185, 392186,
#        392188, 392189, 392190, 392191, 392192, 392194, 392195, 392196,
#        392197, 392198, 392199, 392200, 392201, 392202, 392203, 392204,
#        392205, 392206, 392207, 392208, 392209, 392210, 392211, 392212,
#        392213, 392214, 392215, 392216, 392217, 392218, 392219, 392220,
#        392221, 392222, 392223, 392224, 392225, 392226, 392227, 392228,
# ...

# %%
match_1=deliveries[deliveries['match_id']==335984]

# %%
match_1.head()
# Out:
#      match_id  inning      batting_team      bowling_team  over  ball  \
# 473    335984       1  Rajasthan Royals  Delhi Daredevils     0     1
# 474    335984       1  Rajasthan Royals  Delhi Daredevils     0     2
# 475    335984       1  Rajasthan Royals  Delhi Daredevils     0     3
# 476    335984       1  Rajasthan Royals  Delhi Daredevils     0     4
# 477    335984       1  Rajasthan Royals  Delhi Daredevils     0     5
#
#       batter      bowler non_striker  batsman_runs  extra_runs  total_runs  \
# 473  T Kohli  GD McGrath   YK Pathan           0.0         0.0         0.0
# 474  T Kohli  GD McGrath   YK Pathan           0.0         0.0         0.0
# 475  T Kohli  GD McGrath   YK Pathan           0.0         0.0         0.0
# 476  T Kohli  GD McGrath   YK Pathan           0.0         1.0         1.0
# 477  T Kohli  GD McGrath   YK Pathan           0.0         0.0         0.0
#
#     extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
match_1.shape
# Out:
# (219, 17)

# %%
rr=match_1[match_1['inning']==1]

# %%
rr
# Out:
#      match_id  inning      batting_team      bowling_team  over  ball  \
# 473    335984       1  Rajasthan Royals  Delhi Daredevils     0     1
# 474    335984       1  Rajasthan Royals  Delhi Daredevils     0     2
# 475    335984       1  Rajasthan Royals  Delhi Daredevils     0     3
# 476    335984       1  Rajasthan Royals  Delhi Daredevils     0     4
# 477    335984       1  Rajasthan Royals  Delhi Daredevils     0     5
# ..        ...     ...               ...               ...   ...   ...
# 590    335984       1  Rajasthan Royals  Delhi Daredevils    19     2
# 591    335984       1  Rajasthan Royals  Delhi Daredevils    19     3
# 592    335984       1  Rajasthan Royals  Delhi Daredevils    19     4
# 593    335984       1  Rajasthan Royals  Delhi Daredevils    19     5
# 594    335984       1  Rajasthan Royals  Delhi Daredevils    19     6
#
#          batter      bowler non_striker  batsman_runs  extra_runs  total_runs  \
# ...

# %%
rr['batsman_runs'].value_counts()
# Out:
# batsman_runs
# 0.0    60
# 1.0    42
# 4.0    14
# 6.0     3
# 2.0     3
# Name: count, dtype: int64

# %%
rr['dismissal_kind'].value_counts()
# Out:
# dismissal_kind
# bowled     3
# caught     2
# run out    2
# lbw        1
# Name: count, dtype: int64

# %%
delhi=match_1[match_1['inning']==2]

# %%
delhi
# Out:
#      match_id  inning      batting_team      bowling_team  over  ball  \
# 595    335984       2  Delhi Daredevils  Rajasthan Royals     0     1
# 596    335984       2  Delhi Daredevils  Rajasthan Royals     0     2
# 597    335984       2  Delhi Daredevils  Rajasthan Royals     0     3
# 598    335984       2  Delhi Daredevils  Rajasthan Royals     0     4
# 599    335984       2  Delhi Daredevils  Rajasthan Royals     0     5
# ..        ...     ...               ...               ...   ...   ...
# 687    335984       2  Delhi Daredevils  Rajasthan Royals    14     4
# 688    335984       2  Delhi Daredevils  Rajasthan Royals    14     5
# 689    335984       2  Delhi Daredevils  Rajasthan Royals    14     6
# 690    335984       2  Delhi Daredevils  Rajasthan Royals    14     7
# 691    335984       2  Delhi Daredevils  Rajasthan Royals    15     1
#
#         batter      bowler non_striker  batsman_runs  extra_runs  total_runs  \
# ...

# %%
delhi['batsman_runs'].value_counts()
# Out:
# batsman_runs
# 1.0    38
# 0.0    37
# 4.0    18
# 2.0     3
# 6.0     1
# Name: count, dtype: int64

# %%
delhi['dismissal_kind'].value_counts()
# Out:
# dismissal_kind
# bowled    1
# Name: count, dtype: int64

# %%
delhi['batter'].value_counts()
# Out:
# batter
# G Gambhir    49
# S Dhawan     44
# V Sehwag      4
# Name: count, dtype: int64

# %%
rr['batter'].value_counts()
# Out:
# batter
# RA Jadeja     24
# D Salunkhe    20
# M Kaif        19
# SR Watson     15
# T Kohli       13
# SK Warne      13
# SK Trivedi     7
# YK Pathan      5
# M Rawat        4
# DS Lehmann     2
# Name: count, dtype: int64
